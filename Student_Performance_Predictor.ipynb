# %% [markdown]
# # **Student Performance Prediction**
#
# This is a Machine Learning Data Science program that basically predicts student performance for a specific test. It takes in multiple factors in order to correctly anticipate student performance index. It uses a highly advanced mathematical technique called linear Regression.
#
# ## **What this projects includes**
#
# This project offers a number of different products representations and utilities:
#
#
# 1.   It offers the code for the actual model, the code which trains the model and the code which verifies the model
# 2.   This includes instructions on the implementation of the model, it shows how this code can be implemented into different applications with a mere three lines of configuration.
# 3.   This project provides visualisation of the data using many types of plots all powered by seaborn.
#
#
# ## **How it can be used?**
#
# This code can be used for many things, wether you are a developer and need a student performance model integrated into your website or wether you are a student who needs to forecast their next grade this model has you covered.

# %% [markdown]
# ## **Data Citation**
#
# https://www.kaggle.com/datasets/nikhil7280/student-performance-multiple-linear-regression

# %% [markdown]
# ## **Creating the Model**

# %% [markdown]
# ### **Importing the Necessary Libraries**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns

db = pd.read_csv('Student_Performance.csv')
db.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %% [markdown]
# ### **Understanding the Data**

# %%
db.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# max                            9.000000         100.000000

# %%
sns.pairplot(db, kind='scatter', plot_kws={'alpha': 0.4})

# %%
sns.lmplot(x='Previous Scores', y='Performance Index', data=db, scatter_kws={'alpha': 0.05})

# %%
sns.lmplot(x='Hours Studied', y='Performance Index', data=db, scatter_kws={'alpha': 0.05})

# %% [markdown]
# ### **Splitting into X and Y**

# %%
X = db[['Hours Studied', 'Previous Scores', 'Sleep Hours', 'Sample Question Papers Practiced']]
y = db['Performance Index']

# %%
X
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced
# 0                                    1
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    5
# ...                                ...
# 9995                                 2
# 9996                                 5
# 9997                                 5
# 9998                                 0
# 9999                                 1
#
# [10000 rows x 4 columns]

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %% [markdown]
# ### **Splitting the data into Train and Test**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 9069              4               99            6
# 2603              6               90            9
# 7738              8               57            6
# 1579              6               92            8
# 5058              6               64            8
# ...             ...              ...          ...
# 5734              8               50            6
# 5191              4               68            9
# 5390              9               48            7
# 860               1               47            9
# 7270              2               46            6
#
#       Sample Question Papers Practiced
# 9069                                 1
# 2603                                 3
# 7738                                 1
# 1579                                 7
# 5058                                 4
# ...                                ...
# 5734                                 6
# 5191                                 3
# 5390                                 6
# 860                                  0
# 7270                                 6
#
# [7000 rows x 4 columns]

# %%
y_train
# Out:
# 9069    82.0
# 2603    79.0
# 7738    50.0
# 1579    81.0
# 5058    52.0
#         ...
# 5734    48.0
# 5191    51.0
# 5390    44.0
# 860     20.0
# 7270    24.0
# Name: Performance Index, Length: 7000, dtype: float64

# %%
X_test
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 6252              5               69            8
# 4684              2               46            4
# 1731              7               56            7
# 4742              6               42            8
# 4521              7               53            4
# ...             ...              ...          ...
# 8014              6               42            9
# 1074              2               60            7
# 3063              5               48            6
# 6487              3               86            9
# 4705              6               43            6
#
#       Sample Question Papers Practiced
# 6252                                 2
# 4684                                 8
# 1731                                 5
# 4742                                 5
# 4521                                 6
# ...                                ...
# 8014                                 5
# 1074                                 7
# 3063                                 4
# 6487                                 5
# 4705                                 4
#
# [3000 rows x 4 columns]

# %%
y_test
# Out:
# 6252    51.0
# 4684    20.0
# 1731    46.0
# 4742    28.0
# 4521    41.0
#         ...
# 8014    32.0
# 1074    40.0
# 3063    33.0
# 6487    69.0
# 4705    29.0
# Name: Performance Index, Length: 3000, dtype: float64

# %% [markdown]
# ### **Measuring the Accuracy**

# %%
model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

# %%
sns.scatterplot(x=predictions, y=y_test)
# Out:
# <Axes: ylabel='Performance Index'>

# %%
residuals = y_test - predictions

# %%
sns.displot(residuals, kde=True)

# %% [markdown]
# ## **Implementation**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns

db = pd.read_csv('Student_Performance.csv')


class GradePredictor:
  def __init__(self):
    self.model = LinearRegression()
    self.X = db[['Hours Studied', 'Previous Scores', 'Sleep Hours', 'Sample Question Papers Practiced']]
    self.y = db['Performance Index']

  def predict(self, hours_studied, previous_scores, sleep_hours, sample_question_papers_practiced):
    self.model.fit(X, y)
    predictions = self.model.predict([[hours_studied, previous_scores, sleep_hours, sample_question_papers_practiced]])
    return predictions

model = GradePredictor()
model.predict(4, 67, 9, 40)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([57.99001655])
